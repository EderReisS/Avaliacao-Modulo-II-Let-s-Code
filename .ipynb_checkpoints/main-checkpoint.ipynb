# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# !python3 api_credit.py
# Out:
#  * Serving Flask app 'api_credit' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 108-279-643
# 127.0.0.1 - - [25/Nov/2021 17:16:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Nov/2021 17:16:26] "GET /favicon.ico HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/home/eder/DevProjects/Avaliacao-Modulo-II-Let-s-Code/env/lib/python3.9/site-packages/flask/app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/home/eder/DevProjects/Avaliacao-Modulo-II-Let-s-Code/env/lib/python3.9/site-packages/flask/app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
# ...
